# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv("Unemployment_Rate_upto_11_2020[1].csv")
data.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
data.shape
# Out:
# (267, 9)

# %%
data.columns
# Out:
# Index(['States', 'Date', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Region',
#        'longitude', 'latitude'],
#       dtype='object')

# %%
data.dtypes
# Out:
# States                                  object
# Date                                    object
# Frequency                               object
# Estimated Unemployment Rate            float64
# Estimated Employed                       int64
# Estimated Labour Participation Rate    float64
# Region                                  object
# longitude                              float64
# latitude                               float64
# dtype: object

# %%
print(data.isnull().sum())
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %% [markdown]
# # Observation of January

# %%
result = df['Date'] ==  '2020-01-31'
jan = df[result]
jan
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 0      Andhra Pradesh 2020-01-31         M                         5.48
# 10              Assam 2020-01-31         M                         4.66
# 20              Bihar 2020-01-31         M                        10.61
# 30       Chhattisgarh 2020-01-31         M                         9.65
# 40              Delhi 2020-01-31         M                        22.23
# 50                Goa 2020-01-31         M                         8.89
# 60            Gujarat 2020-01-31         M                         5.54
# 70            Haryana 2020-01-31         M                        20.34
# 80   Himachal Pradesh 2020-01-31         M                        16.83
# 90    Jammu & Kashmir 2020-01-31         M                        21.08
# 99          Jharkhand 2020-01-31         M                        10.61
# 109         Karnataka 2020-01-31         M                         2.86
# ...

# %%
x = jan['States']
y = jan['Estimated Unemployment Rate']

plt.title('UnEmployment rate in January')
plt.barh(x,y,height=0.5)
plt.show()

# %%
# jan_max=pd.DataFrame(df.loc[jan['Estimated Unemployment Rate'].idxmax()])
jan_max=df.loc[jan['Estimated Unemployment Rate'].idxmax()]
jan_max
# Out:
# States                                             Tripura
# Date                                   2020-01-31 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                          32.67
# Estimated Employed                                 1508130
# Estimated Labour Participation Rate                  69.69
# Region                                           Northeast
# longitude                                          23.9408
# latitude                                           91.9882
# Name: 227, dtype: object

# %% [markdown]
# # Observation of February

# %%
result = df['Date'] ==  '2020-02-29'
feb = df[result]
feb
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 1      Andhra Pradesh 2020-02-29         M                         5.83
# 11              Assam 2020-02-29         M                         4.41
# 21              Bihar 2020-02-29         M                        10.29
# 31       Chhattisgarh 2020-02-29         M                         8.38
# 41              Delhi 2020-02-29         M                        14.84
# 51                Goa 2020-02-29         M                         2.81
# 61            Gujarat 2020-02-29         M                         6.38
# 71            Haryana 2020-02-29         M                        25.77
# 81   Himachal Pradesh 2020-02-29         M                        16.84
# 91    Jammu & Kashmir 2020-02-29         M                        20.78
# 100         Jharkhand 2020-02-29         M                        11.85
# 110         Karnataka 2020-02-29         M                         3.61
# ...

# %%
x = feb['States']
y = feb['Estimated Unemployment Rate']

plt.title('UnEmployment rate in February')
plt.barh(x,y,height=0.5)
plt.show()

# %%
feb_max=df.loc[feb['Estimated Unemployment Rate'].idxmax()]
feb_max
# Out:
# States                                             Tripura
# Date                                   2020-02-29 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                           28.4
# Estimated Employed                                 1584686
# Estimated Labour Participation Rate                  68.74
# Region                                           Northeast
# longitude                                          23.9408
# latitude                                           91.9882
# Name: 228, dtype: object

# %% [markdown]
# # Observation of March

# %%
result = df['Date'] ==  '2020-03-31'
mar = df[result]
mar
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 2      Andhra Pradesh 2020-03-31         M                         5.79
# 12              Assam 2020-03-31         M                         4.77
# 22              Bihar 2020-03-31         M                        15.43
# 32       Chhattisgarh 2020-03-31         M                         7.54
# 42              Delhi 2020-03-31         M                        17.04
# 52                Goa 2020-03-31         M                         5.25
# 62            Gujarat 2020-03-31         M                         6.66
# 72            Haryana 2020-03-31         M                        25.05
# 82   Himachal Pradesh 2020-03-31         M                        18.76
# 92    Jammu & Kashmir 2020-03-31         M                        15.50
# 101         Jharkhand 2020-03-31         M                         8.23
# 111         Karnataka 2020-03-31         M                         3.46
# ...

# %%
x = mar['States']
y = mar['Estimated Unemployment Rate']

plt.title('UnEmployment rate in March')
plt.barh(x,y,height=0.5)
plt.show()

# %%
mar_max=df.loc[mar['Estimated Unemployment Rate'].idxmax()]
mar_max
# Out:
# States                                             Tripura
# Date                                   2020-03-31 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                          29.95
# Estimated Employed                                 1511217
# Estimated Labour Participation Rate                  66.89
# Region                                           Northeast
# longitude                                          23.9408
# latitude                                           91.9882
# Name: 229, dtype: object

# %% [markdown]
# # Observation of April

# %%
result = df['Date'] ==  '2020-04-30'
apr = df[result]
apr
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 3      Andhra Pradesh 2020-04-30         M                        20.51
# 13              Assam 2020-04-30         M                        11.06
# 23              Bihar 2020-04-30         M                        46.64
# 33       Chhattisgarh 2020-04-30         M                         3.41
# 43              Delhi 2020-04-30         M                        16.68
# 53                Goa 2020-04-30         M                        13.31
# 63            Gujarat 2020-04-30         M                        18.71
# 73            Haryana 2020-04-30         M                        43.22
# 83   Himachal Pradesh 2020-04-30         M                         2.20
# 102         Jharkhand 2020-04-30         M                        47.09
# 112         Karnataka 2020-04-30         M                        29.84
# 122            Kerala 2020-04-30         M                        16.99
# ...

# %%
x = apr['States']
y = apr['Estimated Unemployment Rate']

plt.title('UnEmployment rate in April')
plt.barh(x,y,height=0.5)
plt.show()

# %%
apr_max=df.loc[apr['Estimated Unemployment Rate'].idxmax()]
apr_max
# Out:
# States                                          Puducherry
# Date                                   2020-04-30 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                          75.85
# Estimated Employed                                  117542
# Estimated Labour Participation Rate                   39.3
# Region                                               South
# longitude                                          11.9416
# latitude                                           79.8083
# Name: 172, dtype: object

# %% [markdown]
#  # Observation of May

# %%
result = df['Date'] ==  '2020-05-31'
may = df[result]
may
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 4      Andhra Pradesh 2020-05-31         M                        17.43
# 14              Assam 2020-05-31         M                         9.55
# 24              Bihar 2020-05-31         M                        45.96
# 34       Chhattisgarh 2020-05-31         M                        10.50
# 44              Delhi 2020-05-31         M                        42.27
# 54                Goa 2020-05-31         M                        21.25
# 64            Gujarat 2020-05-31         M                        12.11
# 74            Haryana 2020-05-31         M                        29.02
# 84   Himachal Pradesh 2020-05-31         M                        26.95
# 93    Jammu & Kashmir 2020-05-31         M                        18.74
# 103         Jharkhand 2020-05-31         M                        59.23
# 113         Karnataka 2020-05-31         M                        19.97
# ...

# %%
x = may['States']
y = may['Estimated Unemployment Rate']

plt.title('UnEmployment rate in May')
plt.barh(x,y,height=0.5)
plt.show()

# %%
may_max=df.loc[may['Estimated Unemployment Rate'].idxmax()]
may_max
# Out:
# States                                           Jharkhand
# Date                                   2020-05-31 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                          59.23
# Estimated Employed                                 4145385
# Estimated Labour Participation Rate                  37.92
# Region                                                East
# longitude                                          23.6102
# latitude                                           85.2799
# Name: 103, dtype: object

# %% [markdown]
# # Observation of June

# %%
result = df['Date'] ==  '2020-06-30'
jun = df[result]
jun
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 5      Andhra Pradesh 2020-06-30         M                         3.31
# 15              Assam 2020-06-30         M                         0.60
# 25              Bihar 2020-06-30         M                        17.82
# 35       Chhattisgarh 2020-06-30         M                        14.23
# 45              Delhi 2020-06-30         M                        18.19
# 55                Goa 2020-06-30         M                         9.96
# 65            Gujarat 2020-06-30         M                         3.20
# 75            Haryana 2020-06-30         M                        26.70
# 85   Himachal Pradesh 2020-06-30         M                        13.47
# 94    Jammu & Kashmir 2020-06-30         M                        17.92
# 104         Jharkhand 2020-06-30         M                        20.95
# 114         Karnataka 2020-06-30         M                         8.44
# ...

# %%
x = jun['States']
y = jun['Estimated Unemployment Rate']

plt.title('UnEmployment rate in June')
plt.barh(x,y,height=0.5)
plt.show()

# %%
jun_max=df.loc[jun['Estimated Unemployment Rate'].idxmax()]
jun_max
# Out:
# States                                             Haryana
# Date                                   2020-06-30 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                           26.7
# Estimated Employed                                 6951934
# Estimated Labour Participation Rate                  42.14
# Region                                               North
# longitude                                          29.0588
# latitude                                           76.0856
# Name: 75, dtype: object

# %% [markdown]
# # Observation of July

# %%
result = df['Date'] ==  '2020-07-31'
jul = df[result]
jul
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 6      Andhra Pradesh 2020-07-31         M                         8.34
# 16              Assam 2020-07-31         M                         3.77
# 26              Bihar 2020-07-31         M                        12.79
# 36       Chhattisgarh 2020-07-31         M                        10.27
# 46              Delhi 2020-07-31         M                        20.30
# 56                Goa 2020-07-31         M                        17.07
# 66            Gujarat 2020-07-31         M                         1.84
# 76            Haryana 2020-07-31         M                        24.18
# 86   Himachal Pradesh 2020-07-31         M                        24.31
# 95    Jammu & Kashmir 2020-07-31         M                        10.88
# 105         Jharkhand 2020-07-31         M                         7.63
# 115         Karnataka 2020-07-31         M                         4.01
# ...

# %%
x = jul['States']
y = jul['Estimated Unemployment Rate']

plt.title('UnEmployment rate in July')
plt.barh(x,y,height=0.5)
plt.show()

# %%
jul_max=df.loc[jul['Estimated Unemployment Rate'].idxmax()]
jul_max
# Out:
# States                                    Himachal Pradesh
# Date                                   2020-07-31 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                          24.31
# Estimated Employed                                 2229456
# Estimated Labour Participation Rate                  48.25
# Region                                               North
# longitude                                          31.1048
# latitude                                           77.1734
# Name: 86, dtype: object

# %% [markdown]
# # Observation of August

# %%
result = df['Date'] ==  '2020-08-31'
aug = df[result]
aug
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 7      Andhra Pradesh 2020-08-31         M                         6.96
# 17              Assam 2020-08-31         M                         5.53
# 27              Bihar 2020-08-31         M                        13.44
# 37       Chhattisgarh 2020-08-31         M                         5.63
# 47              Delhi 2020-08-31         M                        13.79
# 57                Goa 2020-08-31         M                        16.21
# 67            Gujarat 2020-08-31         M                         1.87
# 77            Haryana 2020-08-31         M                        33.50
# 87   Himachal Pradesh 2020-08-31         M                        15.79
# 96    Jammu & Kashmir 2020-08-31         M                        11.09
# 106         Jharkhand 2020-08-31         M                         9.76
# 116         Karnataka 2020-08-31         M                         0.50
# ...

# %%
x = aug['States']
y = aug['Estimated Unemployment Rate']

plt.title('UnEmployment rate in August')
plt.barh(x,y,height=0.5)
plt.show()

# %%
aug_max=df.loc[aug['Estimated Unemployment Rate'].idxmax()]
aug_max
# Out:
# States                                             Haryana
# Date                                   2020-08-31 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                           33.5
# Estimated Employed                                 7113788
# Estimated Labour Participation Rate                  47.32
# Region                                               North
# longitude                                          29.0588
# latitude                                           76.0856
# Name: 77, dtype: object

# %% [markdown]
# # Observation in September

# %%
result = df['Date'] ==  '2020-09-30'
sep = df[result]
sep
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 8      Andhra Pradesh 2020-09-30         M                         6.40
# 18              Assam 2020-09-30         M                         1.19
# 28              Bihar 2020-09-30         M                        11.91
# 38       Chhattisgarh 2020-09-30         M                         1.96
# 48              Delhi 2020-09-30         M                        12.53
# 58                Goa 2020-09-30         M                        15.38
# 68            Gujarat 2020-09-30         M                         3.42
# 78            Haryana 2020-09-30         M                        19.68
# 88   Himachal Pradesh 2020-09-30         M                        12.04
# 97    Jammu & Kashmir 2020-09-30         M                        16.17
# 107         Jharkhand 2020-09-30         M                         8.24
# 117         Karnataka 2020-09-30         M                         2.41
# ...

# %%
x = sep['States']
y = sep['Estimated Unemployment Rate']

plt.title('UnEmployment rate in September')
plt.barh(x,y,height=0.5)
plt.show()

# %%
sep_max=df.loc[sep['Estimated Unemployment Rate'].idxmax()]
sep_max
# Out:
# States                                         Uttarakhand
# Date                                   2020-09-30 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                          22.26
# Estimated Employed                                 2695230
# Estimated Labour Participation Rate                  39.18
# Region                                               North
# longitude                                          30.0668
# latitude                                           79.0193
# Name: 255, dtype: object

# %% [markdown]
# # Observation of October

# %%
result = df['Date'] ==  '2020-10-31'
octo = df[result]
octo
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 9      Andhra Pradesh 2020-10-31         M                         6.59
# 19              Assam 2020-10-31         M                         3.02
# 29              Bihar 2020-10-31         M                         9.82
# 39       Chhattisgarh 2020-10-31         M                         6.62
# 49              Delhi 2020-10-31         M                         6.27
# 59                Goa 2020-10-31         M                        11.54
# 69            Gujarat 2020-10-31         M                         4.03
# 79            Haryana 2020-10-31         M                        27.31
# 89   Himachal Pradesh 2020-10-31         M                        13.46
# 98    Jammu & Kashmir 2020-10-31         M                        16.14
# 108         Jharkhand 2020-10-31         M                        11.80
# 118         Karnataka 2020-10-31         M                         1.58
# ...

# %%
x = octo['States']
y = octo['Estimated Unemployment Rate']

plt.title('UnEmployment rate in October')
plt.barh(x,y,height=0.5)
plt.show()

# %%
octo_max=df.loc[octo['Estimated Unemployment Rate'].idxmax()]
# print(octo_max['States'],octo_max['Estimated Unemployment Rate'])
octo_max
# Out:
# States                                             Haryana
# Date                                   2020-10-31 00:00:00
# Frequency                                                M
# Estimated Unemployment Rate                          27.31
# Estimated Employed                                 6698551
# Estimated Labour Participation Rate                   40.6
# Region                                               North
# longitude                                          29.0588
# latitude                                           76.0856
# Name: 79, dtype: object

# %% [markdown]
# # Final Observation

# %%
temp=[jan_max,feb_max,mar_max,apr_max,may_max,jun_max,jul_max,aug_max,sep_max,octo_max]
maxi=pd.DataFrame(temp)
maxi
# Out:
#                States       Date Frequency  Estimated Unemployment Rate  \
# 227           Tripura 2020-01-31         M                        32.67
# 228           Tripura 2020-02-29         M                        28.40
# 229           Tripura 2020-03-31         M                        29.95
# 172        Puducherry 2020-04-30         M                        75.85
# 103         Jharkhand 2020-05-31         M                        59.23
# 75            Haryana 2020-06-30         M                        26.70
# 86   Himachal Pradesh 2020-07-31         M                        24.31
# 77            Haryana 2020-08-31         M                        33.50
# 255       Uttarakhand 2020-09-30         M                        22.26
# 79            Haryana 2020-10-31         M                        27.31
#
#      Estimated Employed  Estimated Labour Participation Rate     Region  \
# 227             1508130                                69.69  Northeast
# ...

# %%
y = maxi['States']
x=(["Januany","February","March","April","May","June","July","August","September","October"]) 

plt.title('Annual Analysis')
plt.scatter(x,y)
plt.xticks(rotation=90)

plt.show()

# %%
out=[x,maxi['States'],maxi['Estimated Unemployment Rate']]
pd.DataFrame(out)
# Out:
#          0         1        2           3          4        5  \
# 0  Januany  February    March       April        May     June
# 1  Tripura   Tripura  Tripura  Puducherry  Jharkhand  Haryana
# 2    32.67      28.4    29.95       75.85      59.23     26.7
#
#                   6        7            8        9
# 0              July   August    September  October
# 1  Himachal Pradesh  Haryana  Uttarakhand  Haryana
# 2             24.31     33.5        22.26    27.31
